# %%
from sklearn.ensemble import StackingClassifier, RandomForestClassifier
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score, GridSearchCV
from sklearn.tree import plot_tree
from sklearn.metrics import roc_auc_score,accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
cancer = pd.read_csv('BreastCancer.csv')
X = cancer.drop('Class',axis=1)
y = cancer['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=24, test_size=0.3,stratify=y)

# %%
knn = KNeighborsClassifier()
nb = GaussianNB()
dt = DecisionTreeClassifier(random_state=24)
svm = SVC(probability=True,random_state=24)
rf= RandomForestClassifier(random_state=24)

stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('DT',dt),('SVM',svm)]  , final_estimator = rf)

# %%
stack.fit(X_train,y_train)
y_pred = stack.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9571428571428572

# %%
y_pred_proba = stack.predict_proba(X_test)[:,1]
print(roc_auc_score(y_test,y_pred_proba))
# Out:
# 0.9683977455716587

# %%
stack.get_params()
# Out:
# {'cv': None,
#  'estimators': [('KNN', KNeighborsClassifier()),
#   ('NB', GaussianNB()),
#   ('DT', DecisionTreeClassifier(random_state=24)),
#   ('SVM', SVC(probability=True, random_state=24))],
#  'final_estimator__bootstrap': True,
#  'final_estimator__ccp_alpha': 0.0,
#  'final_estimator__class_weight': None,
#  'final_estimator__criterion': 'gini',
#  'final_estimator__max_depth': None,
#  'final_estimator__max_features': 'sqrt',
#  'final_estimator__max_leaf_nodes': None,
#  'final_estimator__max_samples': None,
#  'final_estimator__min_impurity_decrease': 0.0,
#  'final_estimator__min_samples_leaf': 1,
#  'final_estimator__min_samples_split': 2,
#  'final_estimator__min_weight_fraction_leaf': 0.0,
#  'final_estimator__monotonic_cst': None,
#  'final_estimator__n_estimators': 100,
#  'final_estimator__n_jobs': None,
#  'final_estimator__oob_score': False,
#  'final_estimator__random_state': 24,
#  'final_estimator__verbose': 0,
#  'final_estimator__warm_start': False,
#  'final_estimator': RandomForestClassifier(random_state=24),
#  'n_jobs': None,
#  'passthrough': False,
#  'stack_method': 'auto',
#  'verbose': 0,
#  'KNN': KNeighborsClassifier(),
#  'NB': GaussianNB(),
#  'DT': DecisionTreeClassifier(random_state=24),
#  'SVM': SVC(probability=True, random_state=24),
#  'KNN__algorithm': 'auto',
#  'KNN__leaf_size': 30,
#  'KNN__metric': 'minkowski',
#  'KNN__metric_params': None,
#  'KNN__n_jobs': None,
#  'KNN__n_neighbors': 5,
#  'KNN__p': 2,
#  'KNN__weights': 'uniform',
#  'NB__priors': None,
#  'NB__var_smoothing': 1e-09,
#  'DT__ccp_alpha': 0.0,
#  'DT__class_weight': None,
#  'DT__criterion': 'gini',
#  'DT__max_depth': None,
#  'DT__max_features': None,
#  'DT__max_leaf_nodes': None,
#  'DT__min_impurity_decrease': 0.0,
#  'DT__min_samples_leaf': 1,
#  'DT__min_samples_split': 2,
#  'DT__min_weight_fraction_leaf': 0.0,
#  'DT__monotonic_cst': None,
#  'DT__random_state': 24,
#  'DT__splitter': 'best',
#  'SVM__C': 1.0,
#  'SVM__break_ties': False,
#  'SVM__cache_size': 200,
#  'SVM__class_weight': None,
#  'SVM__coef0': 0.0,
#  'SVM__decision_function_shape': 'ovr',
#  'SVM__degree': 3,
#  'SVM__gamma': 'scale',
#  'SVM__kernel': 'rbf',
#  'SVM__max_iter': -1,
#  'SVM__probability': True,
#  'SVM__random_state': 24,
#  'SVM__shrinking': True,
#  'SVM__tol': 0.001,
#  'SVM__verbose': False}

# %%
params= { 'final_estimator__max_depth': [3,5],
        'SVM__C':np.linspace(0.0001,3,5),
        'final_estimator__n_estimators':[10],
         'DT__max_depth':[None,2],
        'passthrough':[True,False]}

gcv = GridSearchCV(stack,param_grid=params,scoring='roc_auc',verbose=3)

# %%
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.985 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.980 total time=   0.3s
# [CV 3/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.999 total time=   0.3s
# [CV 4/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.976 total time=   0.3s
# [CV 5/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.996 total time=   0.3s
# [CV 1/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.409 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.980 total time=   0.3s
# [CV 3/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.977 total time=   0.3s
# [CV 4/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.992 total time=   0.3s
# [CV 5/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.961 total time=   0.3s
# [CV 1/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.991 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.985 total time=   0.3s
# [CV 3/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.999 total time=   0.3s
# [CV 4/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.979 total time=   0.3s
# [CV 5/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.999 total time=   0.3s
# [CV 1/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.433 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.974 total time=   0.3s
# [CV 3/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.995 total time=   0.3s
# [CV 4/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.992 total time=   0.3s
# [CV 5/5] END DT__max_depth=None, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.954 total time=   0.3s
# [CV 1/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.986 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.980 total time=   0.3s
# [CV 3/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.997 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.975 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.997 total time=   0.3s
# [CV 1/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.452 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.979 total time=   0.3s
# [CV 3/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.995 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.992 total time=   0.3s
# [CV 5/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.986 total time=   0.3s
# [CV 1/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.989 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.986 total time=   0.3s
# [CV 3/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.999 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.982 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.995 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.654 total time=   0.4s
# [CV 2/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.960 total time=   0.4s
# [CV 3/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.995 total time=   0.5s
# [CV 4/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.981 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.991 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.986 total time=   0.4s
# [CV 2/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.980 total time=   0.4s
# [CV 3/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.997 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.976 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.997 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.420 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.979 total time=   0.3s
# [CV 3/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=1.000 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.993 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.988 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.988 total time=   0.4s
# [CV 2/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.986 total time=   0.4s
# [CV 3/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.999 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.978 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.999 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.703 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.957 total time=   0.4s
# [CV 3/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.995 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.983 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.993 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.985 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.980 total time=   0.3s
# [CV 3/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.997 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.976 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.996 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.417 total time=   0.4s
# [CV 2/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.979 total time=   0.4s
# [CV 3/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.995 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.993 total time=   0.5s
# [CV 5/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.988 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.988 total time=   0.4s
# [CV 2/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.986 total time=   0.4s
# [CV 3/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.999 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.978 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.999 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.712 total time=   0.4s
# [CV 2/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.961 total time=   0.4s
# [CV 3/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.995 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.980 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.992 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.985 total time=   0.4s
# [CV 2/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.981 total time=   0.5s
# [CV 3/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.997 total time=   0.5s
# [CV 4/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.976 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.997 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.490 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.982 total time=   0.4s
# [CV 3/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.995 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.993 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.989 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.988 total time=   0.4s
# [CV 2/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.987 total time=   0.4s
# [CV 3/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.999 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.978 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 1/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.732 total time=   0.3s
# [CV 2/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.972 total time=   0.4s
# [CV 3/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.995 total time=   0.4s
# [CV 4/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.980 total time=   0.4s
# [CV 5/5] END DT__max_depth=None, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.993 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.978 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.979 total time=   0.3s
# [CV 3/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.999 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.981 total time=   0.3s
# [CV 5/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.3s
# [CV 1/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.969 total time=   0.4s
# [CV 2/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.979 total time=   0.3s
# [CV 3/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.965 total time=   0.3s
# [CV 4/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.987 total time=   0.3s
# [CV 5/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.989 total time=   0.3s
# [CV 1/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.981 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.982 total time=   0.3s
# [CV 3/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.994 total time=   0.3s
# [CV 4/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.981 total time=   0.3s
# [CV 5/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.997 total time=   0.3s
# [CV 1/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.962 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.971 total time=   0.3s
# [CV 3/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.962 total time=   0.3s
# [CV 4/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.977 total time=   0.3s
# [CV 5/5] END DT__max_depth=2, SVM__C=0.0001, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.970 total time=   0.3s
# [CV 1/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.981 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.978 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.981 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.969 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.976 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.999 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.992 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.989 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.987 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.983 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.982 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.994 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.960 total time=   0.4s
# [CV 2/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.969 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.944 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.989 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=0.7500749999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.989 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.981 total time=   0.4s
# [CV 2/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.978 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.976 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.969 total time=   0.4s
# [CV 2/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.977 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.999 total time=   0.5s
# [CV 4/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.987 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.990 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.985 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.983 total time=   0.3s
# [CV 3/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.984 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.995 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.959 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.970 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.944 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.982 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=1.5000499999999999, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.989 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.981 total time=   0.4s
# [CV 2/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.977 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.976 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.969 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.977 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=1.000 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.987 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.992 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.982 total time=   0.4s
# [CV 2/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.983 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.984 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.995 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.957 total time=   0.4s
# [CV 2/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.964 total time=   0.3s
# [CV 3/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.944 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.982 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=2.250025, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.994 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.981 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.981 total time=   0.3s
# [CV 3/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.3s
# [CV 4/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.976 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.3s
# [CV 1/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.969 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.971 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=1.000 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.987 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=0.992 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.982 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.982 total time=   0.3s
# [CV 3/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.998 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.983 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=0.995 total time=   0.4s
# [CV 1/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.963 total time=   0.3s
# [CV 2/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.963 total time=   0.4s
# [CV 3/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.944 total time=   0.4s
# [CV 4/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.971 total time=   0.4s
# [CV 5/5] END DT__max_depth=2, SVM__C=3.0, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=0.992 total time=   0.4s
# GridSearchCV(estimator=StackingClassifier(estimators=[('KNN',
#                                                        KNeighborsClassifier()),
#                                                       ('NB', GaussianNB()),
#                                                       ('DT',
#                                                        DecisionTreeClassifier(random_state=24)),
#                                                       ('SVM',
#                                                        SVC(probability=True,
#                                                            random_state=24))],
#                                           final_estimator=RandomForestClassifier(random_state=24)),
#              param_grid={'DT__max_depth': [None, 2],
#                          'SVM__C': array([1.000000e-04, 7.500750e-01, 1.500050e+00, 2.250025e+00,
#        3.000000e+00]),
#                          'final_estimator__max_depth': [3, 5],
#                          'final_estimator__n_estimators': [10],
#                          'passthrough': [True, False]},
#              scoring='roc_auc', verbose=3)

# %%
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'DT__max_depth': None, 'SVM__C': 0.0001, 'final_estimator__max_depth': 5, 'final_estimator__n_estimators': 10, 'passthrough': True}
# 0.9906635659519422

# %% [markdown]
# Serializing

# %%
import pickle

# %%
best_stack = gcv.best_estimator_

# %%
pkfile = open('stacking_breast_cancer.pkl','wb')

# %%
pickle.dump(best_stack,pkfile)
