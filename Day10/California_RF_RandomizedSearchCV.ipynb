# %%
from sklearn.ensemble import BaggingRegressor
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn import tree
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.metrics import roc_auc_score,accuracy_score,r2_score
from sklearn.model_selection import train_test_split, GridSearchCV,KFold,RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer 
from sklearn.compose import make_column_selector
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import fetch_california_housing

# %%
cali = fetch_california_housing(as_frame=True)

# %%
type(cali)
# Out:
# sklearn.utils._bunch.Bunch

# %%
X,y = fetch_california_housing(as_frame=True,return_X_y = True)

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=24, test_size=0.3)

# %%
rf = RandomForestRegressor()
params = {'max_features' : [2,3,4,5,6],
         'max_depth':[None,3,5],
         'min_samples_split':[2,10,50],
          'min_samples_leaf': [1,10,50],
           'n_estimators':[20,50] }
kFold = KFold(n_splits=5,shuffle=True,random_state=24)

# %%
gcv = GridSearchCV(rf,param_grid= params,cv=kFold ,scoring='r2',verbose=3)

# %%
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 270 candidates, totalling 1350 fits
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.801 total time=   1.1s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.790 total time=   1.0s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.811 total time=   1.0s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.809 total time=   1.1s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.813 total time=   1.1s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.813 total time=   2.6s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.805 total time=   2.7s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.821 total time=   2.6s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.821 total time=   2.8s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.815 total time=   2.7s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=20;, score=0.804 total time=   0.8s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=20;, score=0.779 total time=   0.7s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=20;, score=0.800 total time=   0.7s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=20;, score=0.815 total time=   0.7s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=20;, score=0.811 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.813 total time=   1.9s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.797 total time=   1.9s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.814 total time=   1.9s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.818 total time=   2.2s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.813 total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=50, n_estimators=20;, score=0.791 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=50, n_estimators=20;, score=0.762 total time=   0.6s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=50, n_estimators=20;, score=0.787 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=50, n_estimators=20;, score=0.784 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=50, n_estimators=20;, score=0.786 total time=   0.6s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=0.789 total time=   1.5s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=0.771 total time=   1.5s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=0.792 total time=   1.5s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=0.791 total time=   1.4s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=0.791 total time=   1.5s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=2, n_estimators=20;, score=0.790 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=2, n_estimators=20;, score=0.778 total time=   0.6s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=2, n_estimators=20;, score=0.798 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=2, n_estimators=20;, score=0.793 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=2, n_estimators=20;, score=0.795 total time=   0.6s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.796 total time=   1.6s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.782 total time=   1.5s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.798 total time=   1.5s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.797 total time=   1.5s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.792 total time=   1.5s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=20;, score=0.792 total time=   0.5s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=20;, score=0.774 total time=   0.6s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=20;, score=0.798 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=20;, score=0.793 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=20;, score=0.793 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.792 total time=   1.6s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.782 total time=   1.7s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.797 total time=   1.6s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.794 total time=   1.5s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.796 total time=   1.5s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=50, n_estimators=20;, score=0.772 total time=   0.5s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=50, n_estimators=20;, score=0.752 total time=   0.5s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=50, n_estimators=20;, score=0.784 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=50, n_estimators=20;, score=0.781 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=50, n_estimators=20;, score=0.771 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=50, n_estimators=50;, score=0.788 total time=   1.3s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=50, n_estimators=50;, score=0.768 total time=   1.3s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=50, n_estimators=50;, score=0.782 total time=   1.3s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=50, n_estimators=50;, score=0.777 total time=   1.3s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=10, min_samples_split=50, n_estimators=50;, score=0.787 total time=   1.4s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.742 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.722 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.752 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.744 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.743 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.751 total time=   1.1s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.737 total time=   1.1s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.744 total time=   1.2s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.750 total time=   1.1s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.747 total time=   1.1s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.747 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.720 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.737 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.746 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.740 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=10, n_estimators=50;, score=0.748 total time=   1.1s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=10, n_estimators=50;, score=0.730 total time=   1.0s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=10, n_estimators=50;, score=0.749 total time=   1.0s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=10, n_estimators=50;, score=0.751 total time=   1.2s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=10, n_estimators=50;, score=0.745 total time=   1.2s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=50, n_estimators=20;, score=0.749 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=50, n_estimators=20;, score=0.723 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=50, n_estimators=20;, score=0.749 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=50, n_estimators=20;, score=0.748 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=50, n_estimators=20;, score=0.738 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=50, n_estimators=50;, score=0.746 total time=   1.1s
# [CV 2/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=50, n_estimators=50;, score=0.731 total time=   1.1s
# [CV 3/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=50, n_estimators=50;, score=0.750 total time=   1.0s
# [CV 4/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=50, n_estimators=50;, score=0.746 total time=   1.0s
# [CV 5/5] END max_depth=None, max_features=2, min_samples_leaf=50, min_samples_split=50, n_estimators=50;, score=0.744 total time=   1.0s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.815 total time=   1.4s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.795 total time=   1.4s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.811 total time=   1.4s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.818 total time=   1.4s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.809 total time=   1.5s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.817 total time=   3.8s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.801 total time=   3.6s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.818 total time=   3.5s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.822 total time=   3.7s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.823 total time=   3.7s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=10, n_estimators=20;, score=0

# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.807 total time=   2.9s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=50, n_estimators=20;, score=0.791 total time=   1.0s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=50, n_estimators=20;, score=0.761 total time=   1.0s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=50, n_estimators=20;, score=0.784 total time=   1.0s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=50, n_estimators=20;, score=0.792 total time=   1.0s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=50, n_estimators=20;, score=0.788 total time=   1.0s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=50, n_estimators=50;, score=0.791 total time=   2.6s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=50, n_estimators=50;, score=0.772 total time=   2.6s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=50, n_estimators=50;, score=0.788 total time=   2.8s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=50, n_estimators=50;, score=0.792 total time=   2.5s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=10, min_samples_split=50, n_estimators=50;, score=0.797 total time=   2.4s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.762 total time=   0.7s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.734 total time=   0.8s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.760 total time=   0.7s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.760 total time=   0.7s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.754 total time=   0.8s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.764 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.739 total time=   2.3s
# [CV 3/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.758 total time=   2.3s
# [CV 4/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.763 total time=   2.1s
# [CV 5/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.760 total time=   2.1s
# [CV 1/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.766 total time=   0.8s
# [CV 2/5] END max_depth=None, max_features=4, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.739 total time=   0.8s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 gcv.fit(X,y)
#
# File C:\anaconda-install\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File C:\anaconda-install\Lib\site-packages\sklearn\model_selection\_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File C:\anaconda-install\Lib\site-packages\sklearn\model_selection\_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File C:\anaconda-install\Lib\site-packages\sklearn\model_selection\_search.py:965, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     957 if self.verbose > 0:
#     958     print(
#     959         "Fitting {0} folds for each of {1} candidates,"
#     960         " totalling {2} fits".format(
#     961             n_splits, n_candidates, n_candidates * n_splits
#     962         )
#     963     )
# --> 965 out = parallel(
#     966     delayed(_fit_and_score)(
#     967         clone(base_estimator),
#     968         X,
#     969         y,
#     970         train=train,
#     971         test=test,
#     972         parameters=parameters,
#     973         split_progress=(split_idx, n_splits),
#     974         candidate_progress=(cand_idx, n_candidates),
#     975         **fit_and_score_kwargs,
#     976     )
#     977     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     978         enumerate(candidate_params),
#     979         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     980     )
#     981 )
#     983 if len(out) < 1:
#     984     raise ValueError(
#     985         "No fits were performed. "
#     986         "Was the CV iterator empty? "
#     987         "Were there no candidates?"
#     988     )
#
# File C:\anaconda-install\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File C:\anaconda-install\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File C:\anaconda-install\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File C:\anaconda-install\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File C:\anaconda-install\Lib\site-packages\sklearn\model_selection\_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File C:\anaconda-install\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File C:\anaconda-install\Lib\site-packages\sklearn\ensemble\_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File C:\anaconda-install\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File C:\anaconda-install\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File C:\anaconda-install\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File C:\anaconda-install\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File C:\anaconda-install\Lib\site-packages\sklearn\ensemble\_forest.py:192, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     189     elif class_weight == "balanced_subsample":
#     190         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 192     tree._fit(
#     193         X,
#     194         y,
#     195         sample_weight=curr_sample_weight,
#     196         check_input=False,
#     197         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     198     )
#     199 else:
#     200     tree._fit(
#     201         X,
#     202         y,
#    (...)
#     205         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     206     )
#
# File C:\anaconda-install\Lib\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
print(gcv.best_params_)
print(gcv.best_score_)

# %% [markdown]
# ### RandomizedSearchCV

# %% [markdown]
# RandomizedSearchCV draws a random sample from all the possible parameter sets and then chooses the best parameter condition.

# %%
rf = RandomForestRegressor(random_state=24,oob_score=True)
params = {'max_features' : [2,3,4,5,6],
         'max_depth':[None,3,5],
         'min_samples_split':[2,10,50],
          'min_samples_leaf': [1,10,50],
           'n_estimators':[20,50] }
kFold = KFold(n_splits=5,shuffle=True,random_state=24)

# %%
rgcv = RandomizedSearchCV(rf,param_distributions= params,cv=kFold ,scoring='r2',verbose=3,random_state=24)

# %%
rgcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.664 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.639 total time=   0.3s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.661 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.663 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.648 total time=   0.4s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.540 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.513 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.535 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.532 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.525 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.576 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.551 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.577 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.570 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=6, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.571 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=50, n_estimators=20;, score=0.676 total time=   0.6s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=50, n_estimators=20;, score=0.647 total time=   0.7s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=50, n_estimators=20;, score=0.665 total time=   0.6s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=50, n_estimators=20;, score=0.672 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=50, n_estimators=20;, score=0.669 total time=   0.6s
# [CV 1/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.800 total time=   3.9s
# [CV 2/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.780 total time=   3.6s
# [CV 3/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.796 total time=   3.5s
# [CV 4/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.804 total time=   3.5s
# [CV 5/5] END max_depth=None, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.800 total time=   4.0s
# [CV 1/5] END max_depth=5, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.676 total time=   1.4s
# [CV 2/5] END max_depth=5, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.649 total time=   1.3s
# [CV 3/5] END max_depth=5, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.667 total time=   1.3s
# [CV 4/5] END max_depth=5, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.672 total time=   1.3s
# [CV 5/5] END max_depth=5, max_features=4, min_samples_leaf=50, min_samples_split=2, n_estimators=50;, score=0.664 total time=   1.3s
# [CV 1/5] END max_depth=5, max_features=5, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.677 total time=   0.6s
# [CV 2/5] END max_depth=5, max_features=5, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.646 total time=   0.6s
# [CV 3/5] END max_depth=5, max_features=5, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.665 total time=   0.6s
# [CV 4/5] END max_depth=5, max_features=5, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.670 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=5, min_samples_leaf=50, min_samples_split=2, n_estimators=20;, score=0.669 total time=   0.6s
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.664 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.639 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.661 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.663 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=50, min_samples_split=10, n_estimators=20;, score=0.648 total time=   0.3s
# [CV 1/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.817 total time=   4.1s
# [CV 2/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.803 total time=   3.7s
# [CV 3/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.821 total time=   3.8s
# [CV 4/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.824 total time=   4.0s
# [CV 5/5] END max_depth=None, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.822 total time=   4.1s
# [CV 1/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.799 total time=   4.1s
# [CV 2/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.782 total time=   4.2s
# [CV 3/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.800 total time=   4.3s
# [CV 4/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.805 total time=   4.3s
# [CV 5/5] END max_depth=None, max_features=6, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.801 total time=   4.0s
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=24, shuffle=True),
#                    estimator=RandomForestRegressor(oob_score=True,
#                                                    random_state=24),
#                    param_distributions={'max_depth': [None, 3, 5],
#                                         'max_features': [2, 3, 4, 5, 6],
#                                         'min_samples_leaf': [1, 10, 50],
#                                         'min_samples_split': [2, 10, 50],
#                                         'n_estimators': [20, 50]},
#                    random_state=24, scoring='r2', verbose=3)

# %%
rgcv.best_score_
# Out:
# 0.8172504833002643

# %%
rgcv.best_params_
# Out:
# {'n_estimators': 50,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 3,
#  'max_depth': None}

# %% [markdown]
# ### List of param set(Combinations)

# %%
list(pd.DataFrame(rgcv.cv_results_)['params'])
# Out:
# [{'n_estimators': 20,
#   'min_samples_split': 2,
#   'min_samples_leaf': 50,
#   'max_features': 3,
#   'max_depth': 5},
#  {'n_estimators': 20,
#   'min_samples_split': 10,
#   'min_samples_leaf': 50,
#   'max_features': 3,
#   'max_depth': 3},
#  {'n_estimators': 20,
#   'min_samples_split': 2,
#   'min_samples_leaf': 1,
#   'max_features': 6,
#   'max_depth': 3},
#  {'n_estimators': 20,
#   'min_samples_split': 50,
#   'min_samples_leaf': 1,
#   'max_features': 5,
#   'max_depth': 5},
#  {'n_estimators': 50,
#   'min_samples_split': 10,
#   'min_samples_leaf': 10,
#   'max_features': 5,
#   'max_depth': None},
#  {'n_estimators': 50,
#   'min_samples_split': 2,
#   'min_samples_leaf': 50,
#   'max_features': 4,
#   'max_depth': 5},
#  {'n_estimators': 20,
#   'min_samples_split': 2,
#   'min_samples_leaf': 50,
#   'max_features': 5,
#   'max_depth': 5},
#  {'n_estimators': 20,
#   'min_samples_split': 10,
#   'min_samples_leaf': 50,
#   'max_features': 3,
#   'max_depth': 5},
#  {'n_estimators': 50,
#   'min_samples_split': 2,
#   'min_samples_leaf': 1,
#   'max_features': 3,
#   'max_depth': None},
#  {'n_estimators': 50,
#   'min_samples_split': 2,
#   'min_samples_leaf': 10,
#   'max_features': 6,
#   'max_depth': None}]
